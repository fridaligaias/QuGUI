# %% [markdown]
# <a href="https://colab.research.google.com/github/fridaligaias/QuGUI/blob/v2_qugui/GRC_QuGUI_1_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Phase phi
#
# domande-uniformalismo
# 1. vericale - su/giu
# 1. lungo l'asse x?
#   * si, direzione positiva/negativa
# 1. lungo l'asse y?
#   * si, direzione positiva/negativa
#
# (da carte di dio) es. atomi magnetici, e.g. ferro
# - fascio di atomi
#  - fatto passare tra calamita
#   - caso classico:
#     - i magneti andrebbere in tutte le direzioni, espanderebbe il fascio di magneti in tutte le direzione, il fascio viene allargato
#  - ma nell'esperimento non succede,
#     - si divide in due [il fascio]
#        - la proiezzione lungo l'asse x è, o su o giu
#             - si divide in due [50/50]
#  - se si prende un  fascio e
#     - si passa per una calamite a cornetto con orientazzione verso destra, [a forma di C ], una parte del fascio "sara tutto in su",
#         - se dopo si passa per un calamite a cornetto con orientazione verso in su [ a forma di U ], la domanda combia, non importano i risultati dalla precedente, risposta diventa, o destra o sinistra
#
#  - c'è sempre un contatto con la meccanica classica
#      - anche se in prattica le domande sono quelle [3]
#
# - l'idea che un ogetto abbia una direzione, da qualche parte sta scritta,
#      - ma come si recupera? - sta scritta nello stato
#
# - sello stato è completamente indefinito
#    - ha [comunque?] una probabilità di essere su o giu
#
# il nuovo valore theta, potrebbe essere, per esempio
# - 1/3 su, 2/3 giu,
#      - quindi 1/3 andrà su e 2/3 giu
#         - questo stato è inclinato, asseconda come cambi theta
#
# se si vuole misurare theta,
# - si deve misurare il rapporto d'intensità tra i valori che hanno in su/giu
#   - l'orientazione -> l'angolo theta è comparabile con la altitudine
# - l'angolo phi, è l'altro angolo
#   - sempre in sense medio, è comparabile con la longitudine
#
# se theta = 90*
#  - phi = 0,
#     - come è messo nel piano orizzontale, se il magnete divide in due il fascio
#  - se phi è diversa da zero, ci sara una distribuzione diversa nel piano dal magnete pur sendo theta uguale
#
# questo è sempre il volore medio dell'orientazione
#
# - l'orentazione è classicamente ben definita
#     - in meccanica quantistica non è cosi
#           - non cè lo stesso "sharpness"
#                - pero se ci sono tanti e ne prendi i valori medi, allora, in media, ti da una direzione
#                   - deriva da una specie di probabilità
#
# ----
#
# stato -> procedura -> valore medio
#     - procedura = domande
#
#          - i tipi di domande sono una conseguenza matematica del problema
#
#                - un vettore è determinato delle sue componenti
#
#                       - in meccanica classica:
#                            - le misure sono dello stato del vettore - non c'è ambiguità
#                       - differenza tra il modo con cui descrivi un sistema - stato e i valori (cambiano?) quando descrivi il sistema
#
# se hai un sistema, per esempio il nostro "costheta sintheta etc" , quant'è il valore medio della componente z?
#    - si deve fare la procedura per scoprire
#
# si basa tutto sullo stato e su un insieme di osservabili, messe sullo stato
#
# - osservabili - sono componenti x, y, z
#
# MATRICI - OPERATORI GENERALI
#
#      - deto stato, matrici (3, una per ogni direzione)
#
#            - operazioni
#
#            il valore medio della componente lungo z, y, x
#
#
#            - possibili valori che puoi ottenere misurandoli
#                 - o tutto su, o tutto giu, destra, sinistra, avanti dietro
#
# cos'è in sistema/ cosa posso misurare?
#
# - dalla procedura, dato lo stato, cos theta |0> [latitudine] + sin theta ^eiphi |1> [longitudine]
#    - sono parenti stretti dei angoli per descrivere la posizione
# \\
#    - normalmente , si scrivo lo stato in funzione di angoli **simili** a theta e phi, che corrisponfono con angoli che tu misureresti dopo aver fatto la procedura
#
# - per descrivere l'orenzatione di qualcosa, ci sono degli *standard*
#
# la convenzione più usata per le orentazione
#    - l'asse z, partire da una asse z
#
#    - ci servono 2 angoli;
#        - il 1* è l'angolo che la (penna) fa con l'asse z
#              - [parente non uguale al nostro vecchio] angolo theta
#
# [sul orrizontale]
#
# $$\uparrow \implies \theta = 0^o
# \\ \to  \implies \theta = 90^o
# \\ \downarrow \implies \theta =180^o
# $$
#
# questo corrisponde con la latitudine
#
#
# 2. il secondo angolo, la longitudine
#   - prendendo la proiezione nel piano orrizontale, corrisponde a quanto gira
#   - se gira in senso antiorario
#
# $$\to \implies \phi = 0^o
# \\ \uparrow \implies \phi = 90^o
# \\ \leftarrow \implies \phi =180^o
# $$
#
# remembering that now the equation has changed and become:
# $$
# | \psi \rangle = sin \left( \frac{\theta}{2} \right) |0 \rangle + cos \left( \frac{\theta}{2} \right) e^{-i \phi} |1 \rangle
# $$
#
# con il theta e phi di prima, il theta invece di essere l'angolo usuale (positivo), era in giù, rimaneva 0.
#
# se si vuole calcolare il valor medio di z, e ne abbiamo tanti e ne calcoliamo il valore medio, allineamo una calamita nell'asse z e in base alla proporzione del fascio che va su/giu è la misura
#
# si possono ricostruire in  media, che sono in media quelle date da phi e theta
#
# - la procedura
#
#    - vettori $\to$ ampiezze quantistiche
#    - operatori
#
#    $$
#    sin \left( \frac{\theta}{2} \right) \to \text{ basso, }
#    \\cos  \left( \frac{\theta}{2} \right)e^{i \phi} \to \text{ alto}
#    \\
#    \\ \text{3 matrici, 2x2}
#    \\ \left[ \text{messo lungo assez z?} \right] \left[ \text{lungo x? } \right] \left[ \text{lungo y} \right]
#    $$
#
# media dello stato prodotto dalla matrice $\cdot$ vettore
#
# nel nuovo programma theta value is 180* at default
#
# adesso si prende tutta
#    - il risultato è la direzione media
#         - diventa più facile
#
# $vw$ = valore medio che ottengo se faccio tante misure.
#
# es. se è
# $$
# \left( \frac{2}{3} \right) \text{in su, e }  \left( \frac{1}{3} \right) \text{in giù}
# \\ \implies \text{il valor medio e'}\left( \frac{1}{3} \right) \text{in su}
# $$
#
# noi lo facciamo cosi con gli angoli che hanno il valore di quello che ottengo
#
# $$
# \theta \text{ range =} 180
# \\ \phi \text{ range =} 360
# $$
#
# indicazione di dove e logetto.
